# %% [markdown]
# # CURATED REGIONAL EARTHQUAKE WAVEFORMS (CREW) DATASET
# ## Preliminary demo

# %%
import h5py
import utils
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %%
file = h5py.File('0108_crew.hdf5','r')
data = file['data']
example_names = list(data.keys())

# %%
# Plotting 5 random examples
indices = np.random.randint(low=0,high=len(example_names),size=(5,1))
for index in indices:
    
    fig = utils.plot_example(data[example_names[index[0]]])
